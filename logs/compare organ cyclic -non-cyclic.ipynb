# %%
import pandas as pd

# %%
# !ls
# Out:
# Untitled.ipynb		    base-combined-loss-train-g.log  train-base.json
# base-combined-loss-g-d.log  train-base-cyclic.json

# %%
train_base = pd.read_json("train-base.json")
train_base.head()
# Out:
#      Epoch    step    time    mse
# 0  [0/100]  [0/12]  10.011  0.286
# 1  [0/100]  [1/12]   9.409  0.437
# 2  [0/100]  [2/12]   9.363  0.323
# 3  [0/100]  [3/12]   9.229  0.308
# 4  [0/100]  [4/12]   9.298  0.307

# %%
train_base_cyclic = pd.read_json("train-base-cyclic.json")
train_base_cyclic.head()
# Out:
#      Epoch    step   time    mse
# 0  [0/100]  [0/12]  0.977  0.819
# 1  [0/100]  [1/12]  0.469  0.435
# 2  [0/100]  [2/12]  0.540  0.510
# 3  [0/100]  [3/12]  0.414  0.593
# 4  [0/100]  [4/12]  0.445  0.647

# %%
train_base["mse"].plot()

# %%
train_base_cyclic["mse"].plot()

# %%
train_base["time"].plot()

# %%
train_base_cyclic["time"].plot()
